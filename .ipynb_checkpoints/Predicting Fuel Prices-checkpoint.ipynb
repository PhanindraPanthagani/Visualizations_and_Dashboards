# %% [markdown]
# # This notebook is first used to predict fuel prices using fbprophet and then visualize the result using Tableau
#
# 1) Scrape data from BLS website : https://data.bls.gov/pdq/SurveyOutputServlet and clean the data
#
# 2) Use fb prophet to predict future prices
#
# 3) Save the result in an an excel file with a flag for actual or predicted value
#
# 4) Connect to tableau and Visualize the predictions

# %% [markdown]
# # Time Series modelling
#
# 1) Assumptions : One assumption is that data is stationary, meaning that if you take different equal intervals the average or variance of the data is not changing

# %%
import pandas as pd
from fbprophet import Prophet

import requests
import json
import prettytable
import matplotlib.pyplot as plt

# %%
# !pip install prettytable
# Out:
# Requirement already satisfied: prettytable in c:\users\phanindra\anaconda3\envs\timeseries\lib\site-packages (1.0.1)
# Requirement already satisfied: setuptools in c:\users\phanindra\anaconda3\envs\timeseries\lib\site-packages (from prettytable) (50.3.0.post20201006)
# Requirement already satisfied: wcwidth in c:\users\phanindra\anaconda3\envs\timeseries\lib\site-packages (from prettytable) (0.2.5)

# %%
# Scrape data from BLS website 

weburl= " https://data.bls.gov/pdq/SurveyOutputServlet" 
#Series ID from this URL needs to be changed to get different data 

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['APU000074714'], "startyear":"2010", "endyear":"2020"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.csv','w+')
    output.write (x.get_string())
    output.close()

# %%
#This will be written to a file in memory called output.name
print("Output File name is",output.name)
# Out:
# Output File name is APU000074714.csv

# %%
fueldf = pd.read_csv(output.name , sep = "|",skiprows=1)
fueldf.drop(columns = ["Unnamed: 0","Unnamed: 6"],inplace= True)
fueldf
# Out:
#        series id      year    period    value    footnotes
# 0               NaN     NaN       NaN      NaN          NaN
# 1     APU000074714   2019.0    M12       2.587
# 2     APU000074714   2019.0    M11       2.620
# 3     APU000074714   2019.0    M10       2.673
# 4     APU000074714   2019.0    M09       2.630
# ..              ...     ...       ...      ...          ...
# 117   APU000074714   2010.0    M04       2.858
# 118   APU000074714   2010.0    M03       2.780
# 119   APU000074714   2010.0    M02       2.659
# 120   APU000074714   2010.0    M01       2.731
# 121             NaN     NaN       NaN      NaN          NaN
#
# [122 rows x 5 columns]

# %%
#Clean white space in columns by clearing white spaces in string and re-assigning
newcollist =[]
for col in fueldf.columns :
    newcolname = col.replace(" ", "")
    newcollist.append(newcolname)
print("newcollist is ",newcollist)
fueldf.columns = newcollist
fueldf.columns
# Out:
# newcollist is  ['seriesid', 'year', 'period', 'value', 'footnotes']
# Index(['seriesid', 'year', 'period', 'value', 'footnotes'], dtype='object')

# %%
#Remove all rows with footnotes so that we get a clean dataframe 
fueldf.fillna(0,inplace=True)
footnotes_nonzeromask = fueldf.footnotes != 0
fueldf_nofootnote = fueldf.loc[footnotes_nonzeromask,:]
fueldf_nofootnote
# Out:
#            seriesid    year    period  value    footnotes
# 1     APU000074714   2019.0    M12     2.587
# 2     APU000074714   2019.0    M11     2.620
# 3     APU000074714   2019.0    M10     2.673
# 4     APU000074714   2019.0    M09     2.630
# 5     APU000074714   2019.0    M08     2.655
# ..              ...     ...       ...    ...          ...
# 116   APU000074714   2010.0    M05     2.869
# 117   APU000074714   2010.0    M04     2.858
# 118   APU000074714   2010.0    M03     2.780
# 119   APU000074714   2010.0    M02     2.659
# 120   APU000074714   2010.0    M01     2.731
#
# [120 rows x 5 columns]

# %%
fueldf_nofootnote['footnotes'].describe()
# Out:
# count             120
# unique              1
# top
# freq              120
# Name: footnotes, dtype: object

# %%
fueldf_nofootnote['ActualorPredicted'] = 'Actual'
fueldf_nofootnote
# Out:
# C:\Users\Phanindra\Anaconda3\envs\timeseries\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            seriesid    year    period  value    footnotes ActualorPredicted
# 1     APU000074714   2019.0    M12     2.587                         Actual
# 2     APU000074714   2019.0    M11     2.620                         Actual
# 3     APU000074714   2019.0    M10     2.673                         Actual
# 4     APU000074714   2019.0    M09     2.630                         Actual
# 5     APU000074714   2019.0    M08     2.655                         Actual
# ..              ...     ...       ...    ...          ...               ...
# 116   APU000074714   2010.0    M05     2.869                         Actual
# 117   APU000074714   2010.0    M04     2.858                         Actual
# 118   APU000074714   2010.0    M03     2.780                         Actual
# 119   APU000074714   2010.0    M02     2.659                         Actual
# 120   APU000074714   2010.0    M01     2.731                         Actual
#
# [120 rows x 6 columns]

# %% [markdown]
# # 2) Use fb prophet to predict future prices

# %% [markdown]
# fbprophet Needs data in two columns namely "DS" (date column) and "y" the actual column or here the price of fuel

# %%
#Using lambda functions to extract Month number from period
fueldf_nofootnote.loc[:,'Month'] = fueldf_nofootnote.loc[:,'period'].apply(lambda row : row.replace("M",""))
fueldf_nofootnote.loc[:,'Month'] = fueldf_nofootnote.loc[:,'Month'] .astype(int)
fueldf_nofootnote.rename(columns = {'value':'y'},inplace =True)
# Out:
# C:\Users\Phanindra\Anaconda3\envs\timeseries\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Phanindra\Anaconda3\envs\timeseries\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# C:\Users\Phanindra\Anaconda3\envs\timeseries\lib\site-packages\pandas\core\frame.py:4304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
fueldf_nofootnote['ds'] = pd.to_datetime(dict(year=fueldf_nofootnote.year , month=fueldf_nofootnote.Month, day= 1))
fueldf_nofootnote
# Out:
# C:\Users\Phanindra\Anaconda3\envs\timeseries\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            seriesid    year    period      y    footnotes ActualorPredicted  \
# 1     APU000074714   2019.0    M12     2.587                         Actual
# 2     APU000074714   2019.0    M11     2.620                         Actual
# 3     APU000074714   2019.0    M10     2.673                         Actual
# 4     APU000074714   2019.0    M09     2.630                         Actual
# 5     APU000074714   2019.0    M08     2.655                         Actual
# ..              ...     ...       ...    ...          ...               ...
# 116   APU000074714   2010.0    M05     2.869                         Actual
# 117   APU000074714   2010.0    M04     2.858                         Actual
# 118   APU000074714   2010.0    M03     2.780                         Actual
# 119   APU000074714   2010.0    M02     2.659                         Actual
# 120   APU000074714   2010.0    M01     2.731                         Actual
#
#      Month         ds
# 1       12 2019-12-01
# 2       11 2019-11-01
# 3       10 2019-10-01
# 4        9 2019-09-01
# 5        8 2019-08-01
# ..     ...        ...
# 116      5 2010-05-01
# 117      4 2010-04-01
# 118      3 2010-03-01
# 119      2 2010-02-01
# 120      1 2010-01-01
#
# [120 rows x 8 columns]

# %%
fuel_fbp_input = fueldf_nofootnote.loc[:, ['ds','y']]
fuel_fbp_input
# Out:
#             ds      y
# 1   2019-12-01  2.587
# 2   2019-11-01  2.620
# 3   2019-10-01  2.673
# 4   2019-09-01  2.630
# 5   2019-08-01  2.655
# ..         ...    ...
# 116 2010-05-01  2.869
# 117 2010-04-01  2.858
# 118 2010-03-01  2.780
# 119 2010-02-01  2.659
# 120 2010-01-01  2.731
#
# [120 rows x 2 columns]

# %%
plt.figure(figsize=(30,10))
plt.plot(fuel_fbp_input['ds'],fuel_fbp_input['y'])
plt.xlabel('Date',size=30)
plt.ylabel('FuelPrice',size = 30)
# Out:
# Text(0, 0.5, 'FuelPrice')

# %%
fbp_model = Prophet()
fbp_model.fit(fuel_fbp_input)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
help(fbp_model.make_future_dataframe)
# Out:
# Help on method make_future_dataframe in module fbprophet.forecaster:
#
# make_future_dataframe(periods, freq='D', include_history=True) method of fbprophet.forecaster.Prophet instance
#     Simulate the trend using the extrapolated generative model.
#
#     Parameters
#     ----------
#     periods: Int number of periods to forecast forward.
#     freq: Any valid frequency for pd.date_range, such as 'D' or 'M'.
#     include_history: Boolean to include the historical dates in the data
#         frame for predictions.
#
#     Returns
#     -------
#     pd.Dataframe that extends forward from the end of self.history for the
#     requested number of periods.

# %%
#Forecast 1 year into the future 
future = fbp_model.make_future_dataframe(periods = 12 ,freq = 'M', include_history = False )
future
# Out:
#            ds
# 0  2019-12-31
# 1  2020-01-31
# 2  2020-02-29
# 3  2020-03-31
# 4  2020-04-30
# 5  2020-05-31
# 6  2020-06-30
# 7  2020-07-31
# 8  2020-08-31
# 9  2020-09-30
# 10 2020-10-31
# 11 2020-11-30

# %%
# Python
forecast = fbp_model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#            ds      yhat  yhat_lower  yhat_upper
# 0  2019-12-31  2.122284    1.615178    2.646545
# 1  2020-01-31  2.152136    1.637312    2.689590
# 2  2020-02-29  2.372677    1.855393    2.866589
# 3  2020-03-31  2.471691    1.942486    3.001437
# 4  2020-04-30  2.542989    2.009897    3.035491
# 5  2020-05-31  2.470771    2.000262    2.996639
# 6  2020-06-30  2.443094    1.924919    2.941589
# 7  2020-07-31  2.416993    1.879964    2.924577
# 8  2020-08-31  2.405665    1.869442    2.883715
# 9  2020-09-30  2.349572    1.883673    2.881717
# 10 2020-10-31  2.253264    1.706927    2.781854
# 11 2020-11-30  2.159976    1.682276    2.657421

# %%
# Python
fig1 = fbp_model.plot(forecast)

#Visualizing the forecast for the future.

# %%
fig2 = fbp_model.plot_components(forecast)
